# %% [markdown]
# # Phase 5 - Model Building

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# # Phase 5 - Model Building
#
# ## Model 1 - Logistic Regression

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %%
df = pd.read_csv("../data1/Telco-Customer-Churn.csv")

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

df = df.dropna()

# %%
df = df.drop("customerID", axis=1)

# %%
le = LabelEncoder()

binary_cols = [
    "gender",
    "Partner",
    "Dependents",
    "PhoneService",
    "PaperlessBilling",
    "Churn"
]

for col in binary_cols:
    df[col] = le.fit_transform(df[col])

# %%
multi_cols = [
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaymentMethod"
]

df = pd.get_dummies(
    df,
    columns=multi_cols,
    drop_first=True,
    dtype=int
)

# %%
X = df.drop("Churn", axis=1)

y = df["Churn"]

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 scaler = StandardScaler()
#       2
# ----> 3 X_train = scaler.fit_transform(X_train)
#       4
#       5 X_test = scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
lr = LogisticRegression(random_state=42)

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = lr.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7874911158493249

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[915 118]
#  [181 193]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1033
#            1       0.62      0.52      0.56       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %% [markdown]
# ## Logistic Regression Results
#
# ### Model Performance
#
# - Accuracy: **78.75%**
# - Precision (Churn): **62%**
# - Recall (Churn): **52%**
# - F1-Score (Churn): **56%**
#
# ### Observation
#
# - The model performs well in predicting customers who will not churn.
# - Performance on churn customers is moderate due to class imbalance.
# - Logistic Regression provides a good baseline model.
#
# ### Business Insight
#
# The model can help identify customers at risk of leaving the company. However, improving recall for churn customers would make the model more useful for proactive retention campaigns.

# %% [markdown]
# # Model 2 - Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = dt.predict(X_test)

# %%
accuracy_dt = accuracy_score(y_test, y_pred_dt)

print("Decision Tree Accuracy:", accuracy_dt)
# Out:
# Decision Tree Accuracy: 0.7263681592039801

# %%
cm_dt = confusion_matrix(y_test, y_pred_dt)

print(cm_dt)
# Out:
# [[830 203]
#  [182 192]]

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81      1033
#            1       0.49      0.51      0.50       374
#
#     accuracy                           0.73      1407
#    macro avg       0.65      0.66      0.66      1407
# weighted avg       0.73      0.73      0.73      1407

# %% [markdown]
# ## Decision Tree Results
#
# ### Observation
#
# - Decision Tree is a non-linear machine learning algorithm.
# - It learns decision rules from the training data.
# - Model performance was evaluated using Accuracy, Precision, Recall and F1-Score.
#
# ### Business Insight
#
# Decision Trees are easy to interpret and explain to business stakeholders. They can identify which customer characteristics contribute the most to churn prediction.

# %%
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree"
    ],
    "Accuracy": [
        accuracy,
        accuracy_dt
    ]
})

comparison
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.787491
# 1        Decision Tree  0.726368

# %%
plt.figure(figsize=(6,4))

sns.barplot(
    x="Model",
    y="Accuracy",
    data=comparison
)

plt.title("Model Accuracy Comparison")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.figure(figsize=(6,4))
#       2
#       3 sns.barplot(
#       4     x="Model",
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,4))

sns.barplot(
    x="Model",
    y="Accuracy",
    data=comparison
)

plt.title("Model Accuracy Comparison")
plt.show()

# %% [markdown]
# # Model 3 - Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf.predict(X_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 0.7867803837953091

# %%
cm_rf = confusion_matrix(y_test, y_pred_rf)

print(cm_rf)
# Out:
# [[934  99]
#  [201 173]]

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1033
#            1       0.64      0.46      0.54       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.68      0.70      1407
# weighted avg       0.77      0.79      0.77      1407

# %% [markdown]
# ## Random Forest Results
#
# ### Observation
#
# - Random Forest combines multiple decision trees to improve prediction accuracy.
# - It reduces overfitting compared to a single Decision Tree.
# - The model achieved better generalization on unseen customer data.
#
# ### Business Insight
#
# Random Forest is capable of capturing complex customer behavior patterns and is often more reliable for customer churn prediction. It can help businesses identify high-risk customers more accurately.

# %%
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        accuracy,
        accuracy_dt,
        accuracy_rf
    ]
})

comparison
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.787491
# 1        Decision Tree  0.726368
# 2        Random Forest  0.786780

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7,4))

sns.barplot(
    x="Model",
    y="Accuracy",
    data=comparison
)

plt.title("Model Accuracy Comparison")
plt.show()

# %% [markdown]
# ## Model Comparison
#
# ### Observation
#
# - Logistic Regression provides a strong baseline.
# - Decision Tree performed worse due to overfitting.
# - Random Forest improved prediction by combining multiple trees.
#
# ### Business Insight
#
# Random Forest is generally preferred because it provides better accuracy and more stable predictions. It is a strong candidate for deployment in the customer churn prediction system.

# %%
import joblib

# %%
joblib.dump(rf, "../models/customer_churn_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 joblib.dump(rf, "../models/customer_churn_model.pkl")
#
# NameError: name 'rf' is not defined

# %%
print(X.shape)
print(y.shape)
# Out:
# (7032, 30)
# (7032,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5625, 30)
# (1407, 30)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import joblib

joblib.dump(rf, "../models/customer_churn_model.pkl")
# Out:
# ['../models/customer_churn_model.pkl']

# %%
joblib.dump(scaler, "../models/scaler.pkl")
# Out:
# ['../models/scaler.pkl']

# %%
import os

print(os.listdir("../models"))
# Out:
# ['customer_churn_model.pkl', 'scaler.pkl']

# %%
print(X.columns.tolist())
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'MultipleLines_No phone service', 'MultipleLines_Yes', 'InternetService_Fiber optic', 'InternetService_No', 'OnlineSecurity_No internet service', 'OnlineSecurity_Yes', 'OnlineBackup_No internet service', 'OnlineBackup_Yes', 'DeviceProtection_No internet service', 'DeviceProtection_Yes', 'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No internet service', 'StreamingTV_Yes', 'StreamingMovies_No internet service', 'StreamingMovies_Yes', 'Contract_One year', 'Contract_Two year', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check']

# %%
print("\n".join(X.columns))
# Out:
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# PaperlessBilling
# MonthlyCharges
# TotalCharges
# MultipleLines_No phone service
# MultipleLines_Yes
# InternetService_Fiber optic
# InternetService_No
# OnlineSecurity_No internet service
# OnlineSecurity_Yes
# OnlineBackup_No internet service
# OnlineBackup_Yes
# DeviceProtection_No internet service
# DeviceProtection_Yes
# TechSupport_No internet service
# TechSupport_Yes
# StreamingTV_No internet service
# StreamingTV_Yes
# StreamingMovies_No internet service
# StreamingMovies_Yes
# Contract_One year
# Contract_Two year
# PaymentMethod_Credit card (automatic)
# PaymentMethod_Electronic check
# PaymentMethod_Mailed check
